# %%
# ============================================================
# SESSION UTILITY CELL — DO NOT COMMIT THIS CELL
# Clones the repo into Colab and authenticates for push.
# DELETE THIS CELL'S OUTPUT BEFORE ANY GIT PUSH.
# ============================================================
import getpass, os

PAT = getpass.getpass("Enter GitHub PAT: ")

REPO_OWNER = "stevearchuleta"
REPO_NAME  = "riskml-capstone"
CLONE_DIR  = f"/content/{REPO_NAME}"

os.system('git config --global user.email "stevearchuleta21@gmail.com"')
os.system('git config --global user.name  "Steve Archuleta"')

if not os.path.exists(CLONE_DIR):
    os.system(f"git clone https://{REPO_OWNER}:{PAT}@github.com/{REPO_OWNER}/{REPO_NAME}.git {CLONE_DIR}")
else:
    print(f"REPO ALREADY EXISTS AT {CLONE_DIR} — SKIPPING CLONE")

os.chdir(CLONE_DIR)

os.system(f"git remote set-url origin https://{REPO_OWNER}:{PAT}@github.com/{REPO_OWNER}/{REPO_NAME}.git")

print("CURRENT DIRECTORY:", os.getcwd())
# Out:
# Enter GitHub PAT: ··········
# CURRENT DIRECTORY: /content/riskml-capstone

# %% [markdown]
# # Notebook 07:
# # Figures for Reports, App Writing Demos, and Streamlit Dashboard
#
# <div style="border: 2px solid #007acc; background-color: #e6f0ff; padding: 12px; border-radius: 5px; margin-bottom: 15px;">
# <strong>📘 PURPOSE:</strong> A read-only demonstration and visualization notebook that closes the
# capstone presentation chain by assembling final report-quality figures, rendering summary tables,
# and launching a lightweight Streamlit dashboard from pre-computed artifacts. Notebook 07 contains
# <strong>no model training, no walk-forward evaluation, no artifact generation, and no data
# processing</strong>. All inputs are pre-computed artifacts produced by Notebooks 01 through 06
# and saved to <code>reports/tables/</code>, <code>reports/figures/</code>, and
# <code>data/processed/</code>. Any Azure OpenAI narrative integration is confined to Notebook 07
# and does not affect the scientific pipeline. Notebook 07 is excluded from the core capstone
# evaluation chain; <strong>the six core notebooks (NB01–NB06) constitute the complete scientific
# and analytical record of the project.</strong>
# </div>
#
# ---
#
# ## CAPSTONE CONTEXT
#
# <div style="border-left: 4px solid #6a1b9a; padding-left: 12px; margin: 10px 0;">
#
# **Title:**
# <span style="color: purple;"><strong>Causal-Aware, Machine-Learning-Driven Risk Forecasting and Factor Construction:</strong></span> A Python–Azure Pipeline Integrating NLP, Directed Factor Constraints, and Portfolio Analytics
#
# **Thesis:**
# A small, theory-driven manually constrained <span style="color: purple;"><strong>Directed Acyclic Graph (DAG)</strong></span> that restricts information flow can improve the stability and interpretability of ML-based risk forecasting and factor-based portfolio allocation, relative to unconstrained baselines, under regime variation and estimation noise.
#
# **Notebook 07 Role:**
# Notebook 07 is the <span style="color: purple;"><strong>presentation and demonstration layer</strong></span> only. The six core notebooks (NB01–NB06) produced all scientific results. Notebook 07 reads those saved artifacts and assembles polished outputs for the capstone report, the defense video, and the employer-facing portfolio.
#
# </div>
#
# ---
#
# ## WHAT NOTEBOOK 07 WILL AND WILL NOT DO
#
# <div style="border: 2px solid #3c763d; background-color: #dff0d8; padding: 12px; border-radius: 5px;">
# <strong>✅ NOTEBOOK 07 WILL:</strong>
#
# - Load saved CSV, Parquet, PNG, and JSON artifacts from <code>reports/tables/</code>, <code>reports/figures/</code>, and <code>data/processed/</code>
# - Assemble presentation-quality composite figures combining results from multiple notebooks
# - Render final summary tables formatted for direct insertion into the capstone report
# - Launch and document the Streamlit dashboard (<code>app/streamlit_dashboard.py</code>) that reads those same saved artifacts
# - Demonstrate any Azure OpenAI narrative integration for plain-language result summaries
# - Produce the NB07 artifact manifest confirming all display assets are present
# </div>
#
# <div style="border: 2px solid darkred; background-color: #f2dede; padding: 12px; border-radius: 5px; margin-top: 10px;">
# <strong>🚨 NOTEBOOK 07 WILL NOT:</strong>
#
# - Train any model (no XGBoost fit, no MLP fit, no LSTM fit)
# - Run any walk-forward evaluation loop
# - Generate any new CSV or Parquet artifact
# - Call any data API (no yfinance, no FRED, no Alpha Vantage)
# - Modify any artifact produced by NB01–NB06
# - Import or overwrite any file in <code>data/processed/</code>
#
# <strong>Violation of any item above makes Notebook 07 no longer a demo layer —
# it becomes a pipeline notebook and must be treated accordingly.</strong>
# </div>
#
# ---
#
# ## ARTIFACT DEPENDENCY MAP
#
# <div style="border: 2px solid teal; background-color: #e0f7fa; padding: 12px; border-radius: 5px;">
# <strong>📁 ALL INPUTS — PRE-COMPUTED BY NB01–NB06:</strong>
#
# | Source Notebook | Key Artifacts Consumed by NB07 |
# |:----------------|:-------------------------------|
# | **NB04** | `notebook04_entropy_comparison.csv`, `notebook04_causal_vs_baseline_rmse_mae.csv`, `notebook04_dag_figure.png`, `notebook04_prefix_gain_share_SPY.png` |
# | **NB05** | `notebook05_portfolio_performance.csv`, `notebook05_monthly_returns.csv`, `notebook05_risk_targeting_stability.csv`, `notebook05_turnover_summary.csv` |
# | **NB06** | `notebook06_ablation_table.csv`, `notebook06_benchmark_comparison.csv`, `notebook06_dm_test_results.csv`, `notebook06_regime_portfolio_metrics.csv`, `notebook06_stress_drawdown.csv`, `notebook06_factor_exposure_entropy.csv` |
#
# </div>
#
# ---
#
# ## NOTEBOOK 07 STRUCTURE OVERVIEW
#
# | Cell Block | Code Block | Purpose |
# |:-----------|:-----------|:--------|
# | **SETUP** | CODE_BLOCK_A | Imports, paths, artifact existence checks — zero data loading |
# | **FIGURES** | CODE_BLOCK_B | Composite report figures assembled from saved PNGs and CSVs |
# | **TABLES** | CODE_BLOCK_C | Final formatted summary tables for report insertion |
# | **STREAMLIT** | CODE_BLOCK_D | Launch instructions and documented code for `app/streamlit_dashboard.py` |
# | **AZURE OPENAI** | CODE_BLOCK_E | Optional narrative summaries via Azure OpenAI API (demo only) |
# | **MANIFEST** | CODE_BLOCK_F | NB07 artifact manifest — confirms all display assets present |
#
# ---
#
# ## SCOPE LADDER POSITION
#
# <div style="border: 2px solid #ff9933; background-color: #fff3cd; padding: 12px; border-radius: 5px;">
# <strong>⚠️ SCOPE REMINDER:</strong>
#
# Notebook 07 belongs to <strong>Tier 2 and Tier 3</strong> of the capstone scope ladder.
#
# | Tier | Contents | Status |
# |:-----|:---------|:-------|
# | Tier 1 | NB01–NB06 executed, report finalized, artifacts on GitHub | ✅ Complete — WQU submission |
# | Tier 2 | `riskml/` modularized, Dockerfile, GitHub Actions CI, Azure ML stub | 🔧 In progress — job portfolio |
# | Tier 3 | Streamlit dashboard, Azure OpenAI integration, NB07 demo layer | 📍 This notebook |
# | Tier 4 | Full Kubernetes, production inference APIs | 🚫 Out of scope |
#
# Notebook 07 cannot affect the WQU submission grade. Notebook 07 is Steve Archuleta's
# employer-facing portfolio layer.
# </div>
#
# ---
#
# ## REPRODUCIBILITY
#
# <div style="border: 2px solid #3c763d; background-color: #dff0d8; padding: 12px; border-radius: 5px;">
# <strong>✅ REPRODUCIBILITY GUARANTEES:</strong>
#
# | Dimension | Policy |
# |:----------|:-------|
# | **Random Seed** | 692 (inherited from NB01–NB06; no new random operations in NB07) |
# | **No Data Calls** | Zero external API calls — all data pre-loaded from saved artifacts |
# | **No Model Fitting** | Zero `fit()` or `predict()` calls on any model class |
# | **Artifact-Truth Rule** | All numbers displayed in NB07 must match the corresponding saved CSV artifact exactly |
# | **Fresh-Kernel Rule** | Kernel restart and run-all must succeed using only saved artifacts from a clean clone |
# </div>
#
# ---
#
# ## INPUT AND OUTPUT FILES
#
# <div style="border: 2px solid teal; background-color: #e0f7fa; padding: 12px; border-radius: 5px;">
# <strong>📁 INPUT (read-only, from NB01–NB06 saved artifacts):</strong>
#
# - `reports/tables/notebook04_*.csv` — forecast accuracy and entropy results
# - `reports/tables/notebook05_*.csv` — portfolio performance results
# - `reports/tables/notebook06_*.csv` — validation, ablation, regime, stress results
# - `reports/figures/notebook04_*.png` — NB04 figures
# - `reports/figures/notebook05_*.png` — NB05 figures (if present)
# - `reports/figures/notebook06_*.png` — NB06 figures
#
# </div>
#
# <div style="border: 2px solid teal; background-color: #e0f7fa; padding: 12px; border-radius: 5px; margin-top: 10px;">
# <strong>📁 OUTPUT (produced by Notebook 07):</strong>
#
# - `reports/figures/notebook07_composite_*.png` — composite presentation figures
# - `reports/tables/notebook07_final_summary.csv` — final condensed results table
# - `reports/tables/notebook07_artifact_manifest.csv` — NB07 display asset registry
# - `app/streamlit_dashboard.py` — runnable Streamlit dashboard (reads artifacts only)
# </div>
#
# ---
#
# ## FEATURE NAMING AND DAG REFERENCE
#
# <div style="border: 2px solid #6a1b9a; background-color: #f3e5f5; padding: 12px; border-radius: 5px;">
# <strong>🔗 DAG REFERENCE (inherited from NB04):</strong>
#
# <div style="border: 2px solid #6a1b9a; background-color: #f3e5f5; padding: 12px; border-radius: 5px;">
# <strong>🔗 DAG REFERENCE (inherited from NB04):</strong>
#
# <pre>Sentiment  →  Momentum  →  Returns</pre>
# <span style="color: purple;">Path 1: Sentiment <strong>AMPLIFIES</strong> Momentum; Momentum <strong>FORECASTS</strong> Returns</span>
#
# <pre>Value (HML)            →  Returns</pre>
# <span style="color: purple;">Path 2: Value (HML) <strong>EXPLAINS</strong> Returns</span>
#
# <pre>Volatility →  Risk     →  Allocation</pre>
# <span style="color: purple;">Path 3: Volatility <strong>ESTIMATES</strong> Risk; Risk <strong>CONSTRAINS</strong> Allocation</span>
#
# <span style="color: purple;"><strong>Notebook 07 role in the DAG pipeline:</strong></span> Notebook 07 sits entirely outside the DAG execution chain. The DAG constraints were enforced in NB04. Notebook 07 only displays the results of that enforcement.
# </div>
#
# <span style="color: purple;"><strong>NB07 role in the DAG pipeline:</strong></span>
# Notebook 07 sits entirely outside the DAG execution chain. The DAG constraints were enforced in NB04. Notebook 07 only displays the results of that enforcement.
# </div>
#
# ---
#
# *Notebook 07 of 7 | MScFE 690 Capstone | Steven Archuleta | WorldQuant University*

# %% [markdown]
# ***

# %%
# ============
# CODE_BLOCK_A
# ============

# ================================================================
# SETUP — IMPORTS, PATH DEFINITIONS, AND ARTIFACT EXISTENCE CHECKS
# ================================================================

# =========================================
# IMPORT OS FOR OPERATING SYSTEM OPERATIONS
# =========================================
# os provides access to the operating system interface.
# os.getcwd() returns the current working directory as a string —
# this tells the notebook which folder the kernel started in, which
# is needed to locate the repository root reliably.
import os

# =================================================
# IMPORT PATH FOR OBJECT-ORIENTED PATH CONSTRUCTION
# =================================================
# pathlib.Path is Python's modern cross-platform path builder.
# The "/" operator on two Path objects joins them into a single path —
# so REPO_ROOT / "reports" / "tables" works identically on Windows,
# Mac, and Linux (including Colab, which runs Ubuntu Linux).
from pathlib import Path

# ==========================================
# IMPORT PANDAS FOR TABULAR DATA AND DISPLAY
# ==========================================
# pandas is the standard Python library for structured data.
# In NB07, the primary use is loading saved CSVs from NB04–NB06
# and rendering them as formatted HTML tables in the notebook output.
import pandas as pd

# =================================================================
# IMPORT MATPLOTLIB FOR LOADING SAVED PNG FIGURES INTO THE NOTEBOOK
# =================================================================
# matplotlib.pyplot provides the figure / axes API used throughout
# the capstone. matplotlib.image.imread() loads a PNG file from
# disk into a NumPy array. mpimg.imshow() then renders that array
# inline in Jupyter output — allowing NB07 to display pre-computed
# figures from NB04 and NB06 without regenerating them.
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# =================================================
# IMPORT IPYTHON UTILITIES FOR RICH NOTEBOOK OUTPUT
# =================================================
# IPython.display.display() renders pandas DataFrames as formatted
# HTML tables — richer than a plain print() call.
# Image() renders a PNG file inline in the cell output.
# Markdown() renders a markdown string as formatted text.
from IPython.display import display, Image, Markdown

# =====================================================
# CONFIGURE PANDAS TO SHOW FULL COLUMN WIDTHS IN OUTPUT
# =====================================================
# By default pandas truncates long strings with "...".
# Setting max_colwidth to None disables truncation so full
# artifact filenames are always visible in the existence check table.
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", 60)

print("ALL IMPORTS LOADED SUCCESSFULLY")

# =================================================================
# DETECT THE REPOSITORY ROOT REGARDLESS OF WHERE THE KERNEL STARTED
# =================================================================
# Two cases must be handled:
#   Colab:  the clone utility sets cwd to /content/riskml-capstone,
#           so Path(os.getcwd()).name is "riskml-capstone" and
#           REPO_ROOT = _cwd directly.
#   Local Jupyter: opening a notebook inside notebooks/ sets cwd to
#           the notebooks folder, so .parent returns the repo root.
# This two-case check makes the same code work in both environments
# without any manual path editing.
_cwd = Path(os.getcwd())
REPO_ROOT = _cwd.parent if _cwd.name == "notebooks" else _cwd

# ======================================================
# DEFINE THE THREE ARTIFACT DIRECTORY PATHS FOR NB07 USE
# ======================================================
# TABLES_DIR  — all CSV outputs produced by NB04, NB05, NB06
# FIGURES_DIR — all PNG outputs produced by NB04, NB05, NB06
# DATA_DIR    — Parquet files produced by NB01 and NB02
# Defining these once here means every later code block can
# reference TABLES_DIR / "filename.csv" without repeating the
# full absolute path — making the notebook portable and clean.
TABLES_DIR  = REPO_ROOT / "reports" / "tables"
FIGURES_DIR = REPO_ROOT / "reports" / "figures"
DATA_DIR    = REPO_ROOT / "data"    / "processed"

# ===================================================
# PRINT THE RESOLVED PATHS FOR VERIFICATION AND AUDIT
# ===================================================
# Printing these at setup time makes it immediately obvious whether
# the kernel detected the correct repository root. If any path
# looks wrong here, stop and fix the cwd before proceeding.
print(f"\nREPO_ROOT  : {REPO_ROOT}")
print(f"TABLES_DIR : {TABLES_DIR}")
print(f"FIGURES_DIR: {FIGURES_DIR}")
print(f"DATA_DIR   : {DATA_DIR}")

# ==================================================================
# DEFINE THE EXPECTED ARTIFACT REGISTRY ORGANIZED BY SOURCE NOTEBOOK
# ==================================================================
# This dictionary is the single source of truth for every artifact
# NB07 depends on. Keys are human-readable group labels.
# Values are lists of Path objects pointing to each expected file.
# Organizing by source notebook makes it easy to see at a glance
# which upstream notebook must be rerun if an artifact is missing.
ARTIFACT_REGISTRY = {

    "NB04 — TABLES": [
        TABLES_DIR / "notebook04_causal_rmse_mae.csv",
        TABLES_DIR / "notebook04_causal_vs_baseline_rmse_mae.csv",
        TABLES_DIR / "notebook04_entropy_comparison.csv",
        TABLES_DIR / "notebook04_prefix_gain_share.csv",
        TABLES_DIR / "notebook04_causal_feature_importance.csv",
    ],

    "NB04 — FIGURES": [
        FIGURES_DIR / "notebook04_dag_figure.png",
        FIGURES_DIR / "notebook04_forecast_vs_realized_SPY.png",
        FIGURES_DIR / "notebook04_causal_vs_baseline_rmse_delta.png",
        FIGURES_DIR / "notebook04_entropy_comparison.png",
        FIGURES_DIR / "notebook04_prefix_gain_share_SPY.png",
        FIGURES_DIR / "notebook04_causal_feature_importance_SPY.png",
    ],

    "NB05 — TABLES": [
        TABLES_DIR / "notebook05_portfolio_performance.csv",
        TABLES_DIR / "notebook05_monthly_returns.csv",
        TABLES_DIR / "notebook05_risk_targeting_stability.csv",
        TABLES_DIR / "notebook05_turnover_summary.csv",
    ],

    "NB05 — FIGURES": [
        FIGURES_DIR / "notebook05_equity_curves.png",
        FIGURES_DIR / "notebook05_drawdown_comparison.png",
        FIGURES_DIR / "notebook05_realized_vs_target_volatility.png",
        FIGURES_DIR / "notebook05_weight_timeseries.png",
    ],

    "NB06 — TABLES": [
        TABLES_DIR / "notebook06_ablation_table.csv",
        TABLES_DIR / "notebook06_benchmark_comparison.csv",
        TABLES_DIR / "notebook06_dm_test_results.csv",
        TABLES_DIR / "notebook06_regime_forecast_metrics.csv",
        TABLES_DIR / "notebook06_regime_portfolio_metrics.csv",
        TABLES_DIR / "notebook06_stress_drawdown.csv",
        TABLES_DIR / "notebook06_factor_exposure_entropy.csv",
    ],

    "NB06 — FIGURES": [
        FIGURES_DIR / "notebook06_ablation_comparison.png",
        FIGURES_DIR / "notebook06_regime_portfolio_comparison.png",
        FIGURES_DIR / "notebook06_regime_rmse_comparison.png",
        FIGURES_DIR / "notebook06_stress_drawdown.png",
        FIGURES_DIR / "notebook06_factor_exposure_entropy.png",
    ],

}

# =================================================================
# RUN EXISTENCE CHECKS ON ALL EXPECTED ARTIFACTS AND RECORD RESULTS
# =================================================================
# Loop over every (group, path) pair in the registry.
# p.exists() returns True if the file is present on disk, False
# otherwise. Each result is stored as a dictionary row that will
# become one row in the final display DataFrame.
# Leading underscores on variable names mark them as loop-internal
# temporaries that are not needed outside this block.
_rows = []

for _group, _paths in ARTIFACT_REGISTRY.items():
    for _p in _paths:
        _rows.append({
            "SOURCE"  : _group,
            "FILENAME": _p.name,
            "EXISTS"  : "✅  PRESENT" if _p.exists() else "❌  MISSING",
        })

# ====================================================
# CONVERT THE EXISTENCE CHECK RESULTS INTO A DATAFRAME
# ====================================================
# pd.DataFrame() accepts a list of dictionaries and builds a table
# where each dictionary key becomes a column header. The row order
# matches the order items were appended to _rows — which follows
# the ARTIFACT_REGISTRY dictionary order defined above.
EXISTENCE_DF = pd.DataFrame(_rows)

# ====================================================
# DISPLAY THE FULL EXISTENCE CHECK TABLE IN THE OUTPUT
# ====================================================
# The print statements add a visual header above the DataFrame.
# display() renders EXISTENCE_DF as a formatted HTML table —
# more readable than print(df) in Jupyter notebook output.
print("\n" + "=" * 55)
print("  ARTIFACT EXISTENCE CHECK — NB07 DEPENDENCY AUDIT")
print("=" * 55)
display(EXISTENCE_DF)

# ===================================================
# COMPUTE AND PRINT A SUMMARY COUNT OF THE AUDIT PASS
# ===================================================
# These three lines count total, present, and missing artifacts.
# The comparison string must match exactly what was stored in the
# EXISTS column above — including the spaces and emoji characters.
_n_total   = len(EXISTENCE_DF)
_n_present = (EXISTENCE_DF["EXISTS"] == "✅  PRESENT").sum()
_n_missing = _n_total - _n_present

print(f"\nTOTAL ARTIFACTS CHECKED : {_n_total}")
print(f"PRESENT                 : {_n_present}")
print(f"MISSING                 : {_n_missing}")

# ====================================================
# RAISE A WARNING IF ANY REQUIRED ARTIFACTS ARE ABSENT
# ====================================================
# If any artifact is missing, print the filenames so the rerun
# target is immediately obvious — no guessing which notebook to
# open. All missing artifacts must be regenerated by the source
# notebook before any NB07 code block that reads them can proceed.
# If all artifacts are present, print a green clearance message.
if _n_missing > 0:
    _missing_list = EXISTENCE_DF[
        EXISTENCE_DF["EXISTS"] == "❌  MISSING"
    ]["FILENAME"].tolist()
    print("\n⚠️  WARNING — THE FOLLOWING ARTIFACTS ARE MISSING:")
    for _m in _missing_list:
        print(f"   ❌  {_m}")
    print("\n   RERUN THE SOURCE NOTEBOOK BEFORE PROCEEDING.")
else:
    print("\n✅  ALL ARTIFACTS PRESENT — NB07 IS CLEARED TO PROCEED.")
# Out:
# ALL IMPORTS LOADED SUCCESSFULLY
#
# REPO_ROOT  : /content/riskml-capstone
# TABLES_DIR : /content/riskml-capstone/reports/tables
# FIGURES_DIR: /content/riskml-capstone/reports/figures
# DATA_DIR   : /content/riskml-capstone/data/processed
#
# =======================================================
#   ARTIFACT EXISTENCE CHECK — NB07 DEPENDENCY AUDIT
# =======================================================
#             SOURCE                                      FILENAME      EXISTS
# 0    NB04 — TABLES                notebook04_causal_rmse_mae.csv  ✅  PRESENT
# 1    NB04 — TABLES    notebook04_causal_vs_baseline_rmse_mae.csv  ✅  PRESENT
# 2    NB04 — TABLES             notebook04_entropy_comparison.csv  ✅  PRESENT
# 3    NB04 — TABLES              notebook04_prefix_gain_share.csv  ✅  PRESENT
# 4    NB04 — TABLES      notebook04_causal_feature_importance.csv  ✅  PRESENT
# 5   NB04 — FIGURES                     notebook04_dag_figure.png  ✅  PRESENT
# 6   NB04 — FIGURES       notebook04_forecast_vs_realized_SPY.png  ✅  PRESENT
# 7   NB04 — FIGURES  notebook04_causal_vs_baseline_rmse_delta.png  ✅  PRESENT
# 8   NB04 — FIGURES             notebook04_entropy_comparison.png  ✅  PRESENT
# 9   NB04 — FIGURES          notebook04_prefix_gain_share_SPY.png  ✅  PRESENT
# 10  NB04 — FIGURES  notebook04_causal_feature_importance_SPY.png  ✅  PRESENT
# 11   NB05 — TABLES          notebook05_portfolio_performance.csv  ✅  PRESENT
# 12   NB05 — TABLES                notebook05_monthly_returns.csv  ✅  PRESENT
# 13   NB05 — TABLES       notebook05_risk_targeting_stability.csv  ✅  PRESENT
# 14   NB05 — TABLES               notebook05_turnover_summary.csv  ✅  PRESENT
# 15  NB05 — FIGURES                  notebook05_equity_curves.png  ✅  PRESENT
# 16  NB05 — FIGURES            notebook05_drawdown_comparison.png  ✅  PRESENT
# 17  NB05 — FIGURES  notebook05_realized_vs_target_volatility.png  ✅  PRESENT
# 18  NB05 — FIGURES              notebook05_weight_timeseries.png  ✅  PRESENT
# 19   NB06 — TABLES                 notebook06_ablation_table.csv  ✅  PRESENT
# 20   NB06 — TABLES           notebook06_benchmark_comparison.csv  ✅  PRESENT
# 21   NB06 — TABLES                notebook06_dm_test_results.csv  ✅  PRESENT
# 22   NB06 — TABLES        notebook06_regime_forecast_metrics.csv  ✅  PRESENT
# 23   NB06 — TABLES       notebook06_regime_portfolio_metrics.csv  ✅  PRESENT
# 24   NB06 — TABLES                notebook06_stress_drawdown.csv  ✅  PRESENT
# 25   NB06 — TABLES        notebook06_factor_exposure_entropy.csv  ✅  PRESENT
# 26  NB06 — FIGURES            notebook06_ablation_comparison.png  ✅  PRESENT
# 27  NB06 — FIGURES    notebook06_regime_portfolio_comparison.png  ✅  PRESENT
# 28  NB06 — FIGURES         notebook06_regime_rmse_comparison.png  ✅  PRESENT
# 29  NB06 — FIGURES                notebook06_stress_drawdown.png  ✅  PRESENT
# 30  NB06 — FIGURES        notebook06_factor_exposure_entropy.png  ✅  PRESENT
# TOTAL ARTIFACTS CHECKED : 31
# PRESENT                 : 31
# MISSING                 : 0
#
# ✅  ALL ARTIFACTS PRESENT — NB07 IS CLEARED TO PROCEED.

# %%
# ============================================================
# SESSION PUSH UTILITY — RUN AFTER FILE → SAVE (Ctrl+S)
# SET NB_NUMBER TO MATCH THE CURRENT NOTEBOOK BEFORE RUNNING
# DELETE CELL OUTPUT BEFORE COMMITTING THE NOTEBOOK
# ============================================================
import subprocess, os, glob
os.chdir("/content/riskml-capstone")

NB_NUMBER = "07"  # ← NB07 ONLY

# DISCOVER THE ACTUAL NOTEBOOK FILENAME
_NB_MATCHES = glob.glob(f"notebooks/{NB_NUMBER}_*.ipynb")
if not _NB_MATCHES:
    raise FileNotFoundError(f"No notebook matching notebooks/{NB_NUMBER}_*.ipynb found")
_NB_PATH = _NB_MATCHES[0]
print(f"NOTEBOOK: {_NB_PATH}")

# STAGE THE NOTEBOOK FIRST
_r1 = subprocess.run(["git", "add", _NB_PATH], capture_output=True, text=True)
print(_r1.stdout); print(_r1.stderr)

# STAGE ALL NOTEBOOK-PREFIXED TABLE AND FIGURE ARTIFACTS
_r2 = subprocess.run(
    f"git add reports/tables/notebook{NB_NUMBER}_*.csv reports/figures/notebook{NB_NUMBER}_*.png",
    shell=True, capture_output=True, text=True
)
print(_r2.stdout); print(_r2.stderr)

# STAGE APP ARTIFACTS (STREAMLIT DASHBOARD)
_r3 = subprocess.run(
    "git add app/*.py",
    shell=True, capture_output=True, text=True
)
print(_r3.stdout); print(_r3.stderr)

# SHOW WHAT IS STAGED BEFORE COMMITTING
_r4 = subprocess.run(["git", "status", "--short"], capture_output=True, text=True)
print(_r4.stdout)

# PULL REMOTE CHANGES BEFORE COMMITTING TO AVOID DIVERGENCE
_r5 = subprocess.run(["git", "pull", "--rebase", "origin", "main"],
                     capture_output=True, text=True)
print(_r5.stdout); print(_r5.stderr)

# COMMIT WITH USER-PROVIDED MESSAGE
# ⚠️  TYPE A COMMIT MESSAGE BELOW — NOT YOUR PAT
# Example: NB07: added CODE_BLOCK_B composite figures
_COMMIT_MSG = input("Commit message (e.g. NB07: added CODE_BLOCK_A setup): ")
_r6 = subprocess.run(
    ["git", "commit", "-m", _COMMIT_MSG],
    capture_output=True, text=True
)
print(_r6.stdout); print(_r6.stderr)

# PUSH TO REMOTE
_r7 = subprocess.run(["git", "push", "origin", "main"],
                     capture_output=True, text=True)
print(_r7.stdout); print(_r7.stderr)
# Out:
# NOTEBOOK: notebooks/07_app_demo_and_plots.ipynb
#
#
#
# fatal: pathspec 'reports/tables/notebook07_*.csv' did not match any files
#
#
# fatal: pathspec 'app/*.py' did not match any files
#
#
# Already up to date.
#
# From https://github.com/stevearchuleta/riskml-capstone
#  * branch            main       -> FETCH_HEAD
#
# Commit message (e.g. NB07: added CODE_BLOCK_A setup): NB07: add session clone utility and push utility cells
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
#
#
#
# Everything up-to-date
